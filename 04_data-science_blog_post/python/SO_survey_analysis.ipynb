# %% [markdown]
# # Stack Overflow 2017 Survey Analysis
# Author: Simon Thornewill von Essen
#
# Date: 2019-05-23
#
# ## Introduction
#
# [Text Here]

# %%
# Import the holy trinity, long may they reign
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# ... and the rest


# Acquire a sense of taste
plt.style.use("seaborn")
# %matplotlib inline

# %%
# Import dataset
df = pd.read_csv("../dat/survey_results_raw.csv")
schema = pd.read_csv("../dat/survey_results_schema.csv")

df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %% [markdown]
# The main variables that we wanted to measure the effects of last time were the `Salary` and `JobSatisfaction` columns. I want to explore diferent variables so that the analysis is sufficiently different from what was done in the lessons.
#
# As a part of this analysis, I should create three driving questions that I should try to have some answer for by the end of this notebook based on what I can find within this dataset.
#
# Looking through the columns using the schema file, I have found a number of columns that I find interesting:
#
# 1. Employment Status
# 2. How to pronounge "GIF"?
# 3. Is it okay to use Clicky Keys in the office?
# 4. Important attributes when hiring
# 5. Tabs or Spaces
# 6. Influence, how much power people have over certain outcomes in company
